# %%
# Atividade Python - Livia Lima

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = pd.read_csv("C:\\Users\\livrch\\Desktop\\obito_cartorio.txt")
df1
# Out:
#             date state  epidemiological_week_2019  epidemiological_week_2020  \
# 0     2020-01-01    AC                          1                          1
# 1     2020-01-02    AC                          1                          1
# 2     2020-01-03    AC                          1                          1
# 3     2020-01-04    AC                          1                          1
# 4     2020-01-05    AC                          1                          2
# ...          ...   ...                        ...                        ...
# 9877  2020-12-27    TO                         52                         53
# 9878  2020-12-28    TO                         52                         53
# 9879  2020-12-29    TO                          1                         53
# 9880  2020-12-30    TO                          1                         53
# 9881  2020-12-31    TO                          1                         53
#
# ...

# %%
s = df1['state']

t = df1['new_deaths_total_2020']

plt.bar (s, t, color = "#008B8B", lw = 15)
# Out:
# <BarContainer object of 9882 artists>

# %%
df1.sort_values(by ='new_deaths_total_2020', ascending = True)
# Out:
#             date state  epidemiological_week_2019  epidemiological_week_2020  \
# 9881  2020-12-31    TO                          1                         53
# 5123  2020-12-31    PA                          1                         53
# 9880  2020-12-30    TO                          1                         53
# 4757  2020-12-31    MT                          1                         53
# 365   2020-12-31    AC                          1                         53
# ...          ...   ...                        ...                        ...
# 9427  2020-10-04    SP                         40                         41
# 9303  2020-06-02    SP                         23                         23
# 9426  2020-10-03    SP                         40                         40
# 9430  2020-10-07    SP                         41                         41
# 9425  2020-10-02    SP                         40                         40
#
# ...
